# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Notebook
#
# This notebook serves as an introductory exercise for demonstrating proficiency with the Jupyter Notebook environment and listing essential Data Science tools and concepts.
#
# ---
#
# ## Objectives
#
# * Understand basic notebook structure (Markdown and Code cells).
# * List common Data Science tools and languages.
# * Perform simple arithmetic calculations in a code cell.
#
# ---
#
# ## Data Science Languages
#
# * **Python:** Widely used for its versatility and extensive libraries.
# * **R:** Popular for statistical analysis and graphical models.
# * **SQL:** Essential for managing and querying structured data.
# * **Julia:** Known for high-performance numerical and computational science.
# * **Scala:** Often used with Apache Spark for big data processing.
#
# ---
#
# ## Data Science Libraries
#
# * **Pandas:** Data manipulation and analysis (DataFrames).
# * **NumPy:** Numerical computing and array operations.
# * **Matplotlib:** Data visualization and plotting.
# * **Scikit-learn:** Machine learning algorithms.
# * **TensorFlow / PyTorch:** Deep learning frameworks.
#
# ---
#
# ## Data Science Tools Table
#
# | Category | Tool | Description |
# | :--- | :--- | :--- |
# | **Data Management** | MySQL | Open-source relational database. |
# | **Data Integration** | Apache Kafka | Stream processing platform. |
# | **Visualization** | Tableau | Commercial data visualization software. |
# | **Model Deployment** | Docker | Containerization platform for consistent environments. |
#
# ---
#
# ## Arithmetic Examples
#
# The following code cells demonstrate basic arithmetic operations and unit conversion examples.

# %%
#This a simple arithmetic expression to mutiply then add integers
num_a = 5
num_b = 2
num_c = 3
result = (num_a * num_b) + num_c
print(f"The result of ({num_a} * {num_b}) + {num_c} is: {result}")
# Out:
# The result of (5 * 2) + 3 is: 13

# %%
#This will convert 200 minutes to hours by diving by 60
minutes = 200
conversion_factor = 60
hours = minutes / conversion_factor
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours.

# %% [markdown]
# **Objectives:**
# In this notebook, we aim to cover key introductory concepts, including:
# * listing popular languages for Data Science
# * listing important Data Science libraries
# * demonstrating simple arithmetic expressions
# * converting units (minutes to hours)

# %% [markdown]
# ## Author
# [Nrushal Raj]
